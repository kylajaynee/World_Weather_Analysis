# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 740

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        #Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | malakal
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | damara
# Processing Record 4 of Set 1 | kruisfontein
# Processing Record 5 of Set 1 | salalah
# Processing Record 6 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | vardo
# Processing Record 9 of Set 1 | haines junction
# Processing Record 10 of Set 1 | souillac
# Processing Record 11 of Set 1 | itarema
# Processing Record 12 of Set 1 | ilorin
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | katsuura
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | saint-philippe
# Processing Record 18 of Set 1 | gizo
# Processing Record 19 of Set 1 | vatne
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | nuristan
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | natal
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | batagay-alyta
# Processing Record 30 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 31 of Set 1 | lagoa
# Processing Record 32 of Set 1 | hasaki
# Processing Record 33 of Set 1 | shimoda
# Processing Record 34 of Set 1 | burns lake
# Processing Record 35 of Set 1 | matagami
# Processing Record 36 of Set 1 | kaitangata
# Processing Record 37 of Set 1 | senanga
# Processing Record 38 of Set 1 | boden
# Processing Record 39 of Set 1 | wurzburg
# Processing Record 40 of Set 1 | fort saint john
# City not found. Skipping...
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | amapa
# Processing Record 44 of Set 1 | kinshasa
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | rocha
# Processing Record 48 of Set 1 | jawhar
# Processing Record 49 of Set 1 | perth
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 2 | esperance
# Processing Record 5 of Set 2 | klaksvik
# Processing Record 6 of Set 2 | polunochnoye
# Processing Record 7 of Set 2 | la ronge
# Processing Record 8 of Set 2 | touros
# Processing Record 9 of Set 2 | port alfred
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | nhulunbuy
# Processing Record 12 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | new norfolk
# Processing Record 15 of Set 2 | chuhuyiv
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | prince rupert
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | chokurdakh
# Processing Record 20 of Set 2 | vao
# Processing Record 21 of Set 2 | hilo
# Processing Record 22 of Set 2 | codrington
# Processing Record 23 of Set 2 | dolores
# Processing Record 24 of Set 2 | aksarka
# Processing Record 25 of Set 2 | coquimbo
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | fare
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | berlevag
# Processing Record 30 of Set 2 | pemba
# Processing Record 31 of Set 2 | victoria
# Processing Record 32 of Set 2 | lasa
# Processing Record 33 of Set 2 | jalu
# Processing Record 34 of Set 2 | mareeba
# Processing Record 35 of Set 2 | asau
# Processing Record 36 of Set 2 | jiddah
# City not found. Skipping...
# Processing Record 37 of Set 2 | avarua
# Processing Record 38 of Set 2 | maryborough
# Processing Record 39 of Set 2 | san quintin
# Processing Record 40 of Set 2 | seddon
# Processing Record 41 of Set 2 | carnarvon
# Processing Record 42 of Set 2 | faanui
# Processing Record 43 of Set 2 | northam
# Processing Record 44 of Set 2 | lorengau
# Processing Record 45 of Set 2 | ranot
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | merritt island
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | beyneu
# Processing Record 50 of Set 2 | atuona
# Processing Record 1 of Set 3 | port hedland
# Processing Record 2 of Set 3 | santa cruz
# Processing Record 3 of Set 3 | hervey bay
# Processing Record 4 of Set 3 | kulhudhuffushi
# Processing Record 5 of Set 3 | bengkulu
# Processing Record 6 of Set 3 | cherskiy
# Processing Record 7 of Set 3 | vitim
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | sibolga
# Processing Record 10 of Set 3 | fairbanks
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | kapit
# Processing Record 13 of Set 3 | vila franca do campo
# Processing Record 14 of Set 3 | raudeberg
# Processing Record 15 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 16 of Set 3 | tromso
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 3 | provideniya
# Processing Record 20 of Set 3 | ostrovnoy
# Processing Record 21 of Set 3 | chicama
# Processing Record 22 of Set 3 | erenhot
# Processing Record 23 of Set 3 | namibe
# Processing Record 24 of Set 3 | beringovskiy
# Processing Record 25 of Set 3 | jamestown
# Processing Record 26 of Set 3 | xihe
# Processing Record 27 of Set 3 | te anau
# Processing Record 28 of Set 3 | kibaya
# Processing Record 29 of Set 3 | acarau
# Processing Record 30 of Set 3 | zhangye
# Processing Record 31 of Set 3 | kavieng
# Processing Record 32 of Set 3 | sladkovo
# Processing Record 33 of Set 3 | port macquarie
# Processing Record 34 of Set 3 | kutum
# Processing Record 35 of Set 3 | kyshtovka
# Processing Record 36 of Set 3 | draguignan
# Processing Record 37 of Set 3 | lakshettipet
# Processing Record 38 of Set 3 | sitka
# Processing Record 39 of Set 3 | saskylakh
# Processing Record 40 of Set 3 | hay river
# Processing Record 41 of Set 3 | alta floresta
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | pyaozerskiy
# Processing Record 44 of Set 3 | acapulco
# Processing Record 45 of Set 3 | rockport
# Processing Record 46 of Set 3 | necochea
# Processing Record 47 of Set 3 | prince george
# Processing Record 48 of Set 3 | sanguem
# Processing Record 49 of Set 3 | tonj
# Processing Record 50 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | guayaramerin
# Processing Record 3 of Set 4 | nikolskoye
# Processing Record 4 of Set 4 | nome
# Processing Record 5 of Set 4 | sinnamary
# Processing Record 6 of Set 4 | leningradskiy
# Processing Record 7 of Set 4 | stornoway
# Processing Record 8 of Set 4 | qaanaaq
# Processing Record 9 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 4 | hobart
# Processing Record 11 of Set 4 | talcahuano
# Processing Record 12 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 13 of Set 4 | jardim
# Processing Record 14 of Set 4 | tabou
# Processing Record 15 of Set 4 | dikson
# Processing Record 16 of Set 4 | lock haven
# Processing Record 17 of Set 4 | muisne
# Processing Record 18 of Set 4 | gurlan
# Processing Record 19 of Set 4 | bhadasar
# Processing Record 20 of Set 4 | paramonga
# Processing Record 21 of Set 4 | mamallapuram
# Processing Record 22 of Set 4 | loum
# Processing Record 23 of Set 4 | esfarayen
# Processing Record 24 of Set 4 | sur
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 4 | nizhniy odes
# Processing Record 28 of Set 4 | puerto el triunfo
# Processing Record 29 of Set 4 | warmbad
# Processing Record 30 of Set 4 | tual
# Processing Record 31 of Set 4 | marsh harbour
# Processing Record 32 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 4 | duncan
# Processing Record 34 of Set 4 | rorvik
# Processing Record 35 of Set 4 | hithadhoo
# Processing Record 36 of Set 4 | garissa
# Processing Record 37 of Set 4 | neiafu
# Processing Record 38 of Set 4 | padang
# Processing Record 39 of Set 4 | lata
# Processing Record 40 of Set 4 | ekhabi
# Processing Record 41 of Set 4 | buraydah
# Processing Record 42 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 43 of Set 4 | vicuna
# Processing Record 44 of Set 4 | tezu
# Processing Record 45 of Set 4 | labuhan
# Processing Record 46 of Set 4 | williams lake
# Processing Record 47 of Set 4 | mar del plata
# Processing Record 48 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 49 of Set 4 | troitskoye
# Processing Record 50 of Set 4 | oranjemund
# Processing Record 1 of Set 5 | sarahan
# Processing Record 2 of Set 5 | asyut
# Processing Record 3 of Set 5 | bonito
# Processing Record 4 of Set 5 | kirkwall
# Processing Record 5 of Set 5 | chuy
# Processing Record 6 of Set 5 | mandan
# Processing Record 7 of Set 5 | luderitz
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | tigao
# Processing Record 10 of Set 5 | vila velha
# Processing Record 11 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 12 of Set 5 | taltal
# Processing Record 13 of Set 5 | juifang
# City not found. Skipping...
# Processing Record 14 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 5 | ankara
# Processing Record 16 of Set 5 | nova odessa
# Processing Record 17 of Set 5 | damavand
# Processing Record 18 of Set 5 | port lincoln
# Processing Record 19 of Set 5 | teahupoo
# Processing Record 20 of Set 5 | east london
# Processing Record 21 of Set 5 | kamenka
# Processing Record 22 of Set 5 | akdepe
# Processing Record 23 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 5 | cepelare
# Processing Record 25 of Set 5 | vaini
# Processing Record 26 of Set 5 | dalby
# Processing Record 27 of Set 5 | suamico
# Processing Record 28 of Set 5 | khatanga
# Processing Record 29 of Set 5 | asfi
# Processing Record 30 of Set 5 | bathsheba
# Processing Record 31 of Set 5 | port hardy
# Processing Record 32 of Set 5 | yerbogachen
# Processing Record 33 of Set 5 | inongo
# Processing Record 34 of Set 5 | yabrud
# Processing Record 35 of Set 5 | champerico
# Processing Record 36 of Set 5 | porto belo
# Processing Record 37 of Set 5 | stavern
# Processing Record 38 of Set 5 | sadao
# Processing Record 39 of Set 5 | la libertad
# Processing Record 40 of Set 5 | tuktoyaktuk
# Processing Record 41 of Set 5 | hambantota
# Processing Record 42 of Set 5 | sao filipe
# Processing Record 43 of Set 5 | tilichiki
# Processing Record 44 of Set 5 | am timan
# Processing Record 45 of Set 5 | vanimo
# Processing Record 46 of Set 5 | cap-aux-meules
# Processing Record 47 of Set 5 | lavrentiya
# Processing Record 48 of Set 5 | chapais
# Processing Record 49 of Set 5 | sambava
# Processing Record 50 of Set 5 | saint-augustin
# Processing Record 1 of Set 6 | cabinda
# Processing Record 2 of Set 6 | narayanpet
# Processing Record 3 of Set 6 | yelovo
# Processing Record 4 of Set 6 | kattivakkam
# Processing Record 5 of Set 6 | talara
# Processing Record 6 of Set 6 | gilbues
# Processing Record 7 of Set 6 | dalaba
# Processing Record 8 of Set 6 | yellowknife
# Processing Record 9 of Set 6 | norman wells
# Processing Record 10 of Set 6 | iqaluit
# Processing Record 11 of Set 6 | egvekinot
# Processing Record 12 of Set 6 | bokspits
# City not found. Skipping...
# Processing Record 13 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 14 of Set 6 | tashtyp
# Processing Record 15 of Set 6 | mantua
# Processing Record 16 of Set 6 | clyde river
# Processing Record 17 of Set 6 | aklavik
# Processing Record 18 of Set 6 | nanortalik
# Processing Record 19 of Set 6 | kavaratti
# Processing Record 20 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 6 | newcastleton
# Processing Record 22 of Set 6 | yeehaw junction
# City not found. Skipping...
# Processing Record 23 of Set 6 | washington
# Processing Record 24 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 25 of Set 6 | pimentel
# Processing Record 26 of Set 6 | general pico
# Processing Record 27 of Set 6 | itoman
# Processing Record 28 of Set 6 | bud
# Processing Record 29 of Set 6 | florencia
# Processing Record 30 of Set 6 | cayenne
# Processing Record 31 of Set 6 | kushmurun
# Processing Record 32 of Set 6 | biak
# Processing Record 33 of Set 6 | sechura
# Processing Record 34 of Set 6 | bonnyville
# Processing Record 35 of Set 6 | marawi
# Processing Record 36 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 6 | irbil
# Processing Record 38 of Set 6 | falun
# Processing Record 39 of Set 6 | djambala
# Processing Record 40 of Set 6 | belgrade
# Processing Record 41 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 6 | meadow lake
# Processing Record 43 of Set 6 | taunggyi
# Processing Record 44 of Set 6 | dingle
# Processing Record 45 of Set 6 | mynay
# Processing Record 46 of Set 6 | shizukuishi
# Processing Record 47 of Set 6 | bom jesus
# Processing Record 48 of Set 6 | olinda
# Processing Record 49 of Set 6 | palana
# Processing Record 50 of Set 6 | kushiro
# Processing Record 1 of Set 7 | christchurch
# Processing Record 2 of Set 7 | pacific grove
# Processing Record 3 of Set 7 | puerto leguizamo
# Processing Record 4 of Set 7 | kondinskoye
# Processing Record 5 of Set 7 | hamilton
# Processing Record 6 of Set 7 | rio grande
# Processing Record 7 of Set 7 | nyurba
# Processing Record 8 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 7 | tura
# Processing Record 10 of Set 7 | labrea
# Processing Record 11 of Set 7 | balurghat
# Processing Record 12 of Set 7 | grindavik
# Processing Record 13 of Set 7 | coruripe
# Processing Record 14 of Set 7 | tampere
# Processing Record 15 of Set 7 | ust-tsilma
# Processing Record 16 of Set 7 | awjilah
# Processing Record 17 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 7 | coolum beach
# Processing Record 19 of Set 7 | avera
# Processing Record 20 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 7 | podor
# Processing Record 22 of Set 7 | ambilobe
# Processing Record 23 of Set 7 | condega
# Processing Record 24 of Set 7 | ginda
# Processing Record 25 of Set 7 | tithorea
# Processing Record 26 of Set 7 | waipawa
# Processing Record 27 of Set 7 | marienburg
# Processing Record 28 of Set 7 | belaya gora
# Processing Record 29 of Set 7 | moyale
# Processing Record 30 of Set 7 | banda aceh
# Processing Record 31 of Set 7 | arrifes
# Processing Record 32 of Set 7 | taoudenni
# Processing Record 33 of Set 7 | kanigoro
# Processing Record 34 of Set 7 | husavik
# Processing Record 35 of Set 7 | zhezkazgan
# Processing Record 36 of Set 7 | xuddur
# Processing Record 37 of Set 7 | saint anthony
# Processing Record 38 of Set 7 | honiara
# Processing Record 39 of Set 7 | phek
# Processing Record 40 of Set 7 | yulara
# Processing Record 41 of Set 7 | araouane
# Processing Record 42 of Set 7 | comodoro rivadavia
# Processing Record 43 of Set 7 | preobrazheniye
# Processing Record 44 of Set 7 | port moresby
# Processing Record 45 of Set 7 | burica
# City not found. Skipping...
# Processing Record 46 of Set 7 | singkang
# Processing Record 47 of Set 7 | grand gaube
# Processing Record 48 of Set 7 | airai
# Processing Record 49 of Set 7 | haapu
# City not found. Skipping...
# Processing Record 50 of Set 7 | shitkino
# Processing Record 1 of Set 8 | panama city
# Processing Record 2 of Set 8 | kuliyapitiya
# Processing Record 3 of Set 8 | rebrikha
# Processing Record 4 of Set 8 | guerrero negro
# Processing Record 5 of Set 8 | takoradi
# Processing Record 6 of Set 8 | muyezerskiy
# Processing Record 7 of Set 8 | ossora
# Processing Record 8 of Set 8 | cabo san lucas
# Processing Record 9 of Set 8 | damghan
# Processing Record 10 of Set 8 | mount gambier
# Processing Record 11 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 8 | poum
# Processing Record 13 of Set 8 | port lavaca
# Processing Record 14 of Set 8 | boddam
# Processing Record 15 of Set 8 | fairview
# Processing Record 16 of Set 8 | tuatapere
# Processing Record 17 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 8 | macon
# Processing Record 19 of Set 8 | san cristobal
# Processing Record 20 of Set 8 | guiglo
# Processing Record 21 of Set 8 | makakilo city
# Processing Record 22 of Set 8 | starkville
# Processing Record 23 of Set 8 | uberaba
# Processing Record 24 of Set 8 | plettenberg bay
# Processing Record 25 of Set 8 | tapejara
# Processing Record 26 of Set 8 | havelock
# Processing Record 27 of Set 8 | maragogi
# Processing Record 28 of Set 8 | naze
# Processing Record 29 of Set 8 | muli
# Processing Record 30 of Set 8 | kamsack
# Processing Record 31 of Set 8 | akyab
# Processing Record 32 of Set 8 | bambous virieux
# Processing Record 33 of Set 8 | shelburne
# Processing Record 34 of Set 8 | heihe
# Processing Record 35 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 36 of Set 8 | tevriz
# Processing Record 37 of Set 8 | sao joao da barra
# Processing Record 38 of Set 8 | yakeshi
# Processing Record 39 of Set 8 | clinton
# Processing Record 40 of Set 8 | praia
# Processing Record 41 of Set 8 | akureyri
# Processing Record 42 of Set 8 | kudahuvadhoo
# Processing Record 43 of Set 8 | saint george
# Processing Record 44 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 8 | upernavik
# Processing Record 46 of Set 8 | yatou
# Processing Record 47 of Set 8 | golden
# Processing Record 48 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 8 | urucara
# Processing Record 50 of Set 8 | west wendover
# Processing Record 1 of Set 9 | pihuamo
# Processing Record 2 of Set 9 | moranbah
# Processing Record 3 of Set 9 | aleksandrov gay
# Processing Record 4 of Set 9 | eldorado
# Processing Record 5 of Set 9 | shingu
# Processing Record 6 of Set 9 | bubaque
# Processing Record 7 of Set 9 | malanje
# Processing Record 8 of Set 9 | broome
# Processing Record 9 of Set 9 | turukhansk
# Processing Record 10 of Set 9 | saint marys
# Processing Record 11 of Set 9 | red bluff
# Processing Record 12 of Set 9 | adelanto
# Processing Record 13 of Set 9 | talnakh
# Processing Record 14 of Set 9 | marsaxlokk
# Processing Record 15 of Set 9 | horta
# Processing Record 16 of Set 9 | wakkanai
# Processing Record 17 of Set 9 | san ramon
# Processing Record 18 of Set 9 | inirida
# Processing Record 19 of Set 9 | axim
# Processing Record 20 of Set 9 | gamba
# Processing Record 21 of Set 9 | churapcha
# Processing Record 22 of Set 9 | rawson
# Processing Record 23 of Set 9 | cidreira
# Processing Record 24 of Set 9 | kapuskasing
# Processing Record 25 of Set 9 | tungkang
# City not found. Skipping...
# Processing Record 26 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 9 | dunedin
# Processing Record 28 of Set 9 | pisco
# Processing Record 29 of Set 9 | svetlaya
# Processing Record 30 of Set 9 | mount isa
# Processing Record 31 of Set 9 | lakselv
# Processing Record 32 of Set 9 | alofi
# Processing Record 33 of Set 9 | isangel
# Processing Record 34 of Set 9 | caravelas
# Processing Record 35 of Set 9 | grand island
# Processing Record 36 of Set 9 | saint-georges
# Processing Record 37 of Set 9 | bayji
# Processing Record 38 of Set 9 | launceston
# Processing Record 39 of Set 9 | tessalit
# Processing Record 40 of Set 9 | richards bay
# Processing Record 41 of Set 9 | cetraro
# Processing Record 42 of Set 9 | baiyin
# Processing Record 43 of Set 9 | deputatskiy
# Processing Record 44 of Set 9 | saldanha
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | kathu
# Processing Record 47 of Set 9 | cayhagan
# Processing Record 48 of Set 9 | mandalgovi
# Processing Record 49 of Set 9 | baneh
# Processing Record 50 of Set 9 | funtua
# Processing Record 1 of Set 10 | bellefontaine
# Processing Record 2 of Set 10 | torbay
# Processing Record 3 of Set 10 | filadelfia
# Processing Record 4 of Set 10 | san policarpo
# Processing Record 5 of Set 10 | hami
# Processing Record 6 of Set 10 | palmas
# Processing Record 7 of Set 10 | eldikan
# City not found. Skipping...
# Processing Record 8 of Set 10 | morgan city
# Processing Record 9 of Set 10 | munchenbuchsee
# Processing Record 10 of Set 10 | stephenville
# Processing Record 11 of Set 10 | jabiru
# City not found. Skipping...
# Processing Record 12 of Set 10 | shalinskoye
# Processing Record 13 of Set 10 | talkha
# Processing Record 14 of Set 10 | altoona
# Processing Record 15 of Set 10 | vostok
# Processing Record 16 of Set 10 | daru
# Processing Record 17 of Set 10 | pitkyaranta
# Processing Record 18 of Set 10 | kaduna
# Processing Record 19 of Set 10 | saint-pierre
# Processing Record 20 of Set 10 | suez
# Processing Record 21 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 22 of Set 10 | koslan
# Processing Record 23 of Set 10 | morros
# Processing Record 24 of Set 10 | meulaboh
# Processing Record 25 of Set 10 | narsaq
# Processing Record 26 of Set 10 | kallithea
# Processing Record 27 of Set 10 | joshimath
# Processing Record 28 of Set 10 | leshukonskoye
# Processing Record 29 of Set 10 | natchitoches
# Processing Record 30 of Set 10 | forio
# Processing Record 31 of Set 10 | kroonstad
# Processing Record 32 of Set 10 | manado
# Processing Record 33 of Set 10 | karratha
# Processing Record 34 of Set 10 | dzhebariki-khaya
# Processing Record 35 of Set 10 | guerande
# Processing Record 36 of Set 10 | bansko
# Processing Record 37 of Set 10 | aljezur
# Processing Record 38 of Set 10 | caohai
# Processing Record 39 of Set 10 | hualmay
# Processing Record 40 of Set 10 | camacha
# Processing Record 41 of Set 10 | tautira
# Processing Record 42 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 10 | inuvik
# Processing Record 44 of Set 10 | tagab
# Processing Record 45 of Set 10 | la palma
# Processing Record 46 of Set 10 | evensk
# Processing Record 47 of Set 10 | ewa beach
# Processing Record 48 of Set 10 | vila
# Processing Record 49 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 10 | hofn
# Processing Record 1 of Set 11 | adra
# Processing Record 2 of Set 11 | nemuro
# Processing Record 3 of Set 11 | old road
# City not found. Skipping...
# Processing Record 4 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 5 of Set 11 | japura
# Processing Record 6 of Set 11 | seoul
# Processing Record 7 of Set 11 | banamba
# Processing Record 8 of Set 11 | walvis bay
# Processing Record 9 of Set 11 | westport
# Processing Record 10 of Set 11 | bilma
# Processing Record 11 of Set 11 | mali
# Processing Record 12 of Set 11 | fenoarivo
# Processing Record 13 of Set 11 | bilibino
# Processing Record 14 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 15 of Set 11 | sayyan
# Processing Record 16 of Set 11 | mehamn
# Processing Record 17 of Set 11 | tahe
# Processing Record 18 of Set 11 | college
# Processing Record 19 of Set 11 | mayumba
# Processing Record 20 of Set 11 | port shepstone
# Processing Record 21 of Set 11 | seda
# Processing Record 22 of Set 11 | odesskoye
# Processing Record 23 of Set 11 | powell
# Processing Record 24 of Set 11 | masvingo
# Processing Record 25 of Set 11 | srednekolymsk
# Processing Record 26 of Set 11 | balkhash
# Processing Record 27 of Set 11 | yining
# Processing Record 28 of Set 11 | cozumel
# Processing Record 29 of Set 11 | krasnoselkup
# Processing Record 30 of Set 11 | okhotsk
# Processing Record 31 of Set 11 | villa nueva
# Processing Record 32 of Set 11 | pevek
# Processing Record 33 of Set 11 | calama
# Processing Record 34 of Set 11 | skibotn
# Processing Record 35 of Set 11 | maniitsoq
# Processing Record 36 of Set 11 | grenada
# Processing Record 37 of Set 11 | ponta delgada
# Processing Record 38 of Set 11 | mozhga
# Processing Record 39 of Set 11 | umm kaddadah
# Processing Record 40 of Set 11 | martapura
# Processing Record 41 of Set 11 | road town
# Processing Record 42 of Set 11 | san andres
# Processing Record 43 of Set 11 | byron bay
# Processing Record 44 of Set 11 | mackay
# Processing Record 45 of Set 11 | shahrud
# Processing Record 46 of Set 11 | ambulu
# Processing Record 47 of Set 11 | sept-iles
# Processing Record 48 of Set 11 | stutterheim
# Processing Record 49 of Set 11 | dergachi
# Processing Record 50 of Set 11 | sorland
# Processing Record 1 of Set 12 | pinotepa nacional
# Processing Record 2 of Set 12 | acucena
# Processing Record 3 of Set 12 | manzanillo
# Processing Record 4 of Set 12 | gandajika
# Processing Record 5 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 6 of Set 12 | kirakira
# Processing Record 7 of Set 12 | pangnirtung
# Processing Record 8 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 12 | borogontsy
# Processing Record 10 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 12 | praia da vitoria
# Processing Record 12 of Set 12 | yinchuan
# Processing Record 13 of Set 12 | sosnovo-ozerskoye
# Processing Record 14 of Set 12 | buala
# Processing Record 15 of Set 12 | andros town
# Processing Record 16 of Set 12 | swan river
# Processing Record 17 of Set 12 | ust-nera
# Processing Record 18 of Set 12 | muzhi
# Processing Record 19 of Set 12 | teya
# Processing Record 20 of Set 12 | san ignacio
# Processing Record 21 of Set 12 | bowen
# Processing Record 22 of Set 12 | timbakion
# City not found. Skipping...
# Processing Record 23 of Set 12 | vrede
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | karoi
# Processing Record 26 of Set 12 | sataua
# City not found. Skipping...
# Processing Record 27 of Set 12 | urazovo
# Processing Record 28 of Set 12 | katherine
# Processing Record 29 of Set 12 | mecca
# Processing Record 30 of Set 12 | hidalgotitlan
# Processing Record 31 of Set 12 | namatanai
# Processing Record 32 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 33 of Set 12 | russell
# Processing Record 34 of Set 12 | margate
# Processing Record 35 of Set 12 | aromashevo
# Processing Record 36 of Set 12 | tocopilla
# Processing Record 37 of Set 12 | port-gentil
# Processing Record 38 of Set 12 | slave lake
# Processing Record 39 of Set 12 | presidencia roque saenz pena
# Processing Record 40 of Set 12 | verkhniy rohachyk
# Processing Record 41 of Set 12 | slidell
# Processing Record 42 of Set 12 | itaguai
# Processing Record 43 of Set 12 | amli
# Processing Record 44 of Set 12 | ravar
# Processing Record 45 of Set 12 | hobyo
# Processing Record 46 of Set 12 | nurota
# Processing Record 47 of Set 12 | safford
# Processing Record 48 of Set 12 | bondoukou
# Processing Record 49 of Set 12 | lardos
# Processing Record 50 of Set 12 | san luis
# Processing Record 1 of Set 13 | yar-sale
# Processing Record 2 of Set 13 | rantepao
# Processing Record 3 of Set 13 | moosomin
# Processing Record 4 of Set 13 | shakawe
# Processing Record 5 of Set 13 | pudozh
# Processing Record 6 of Set 13 | grimari
# City not found. Skipping...
# Processing Record 7 of Set 13 | pitimbu
# Processing Record 8 of Set 13 | zvornik
# Processing Record 9 of Set 13 | tema
# Processing Record 10 of Set 13 | sturgeon bay
# Processing Record 11 of Set 13 | pasaje
# Processing Record 12 of Set 13 | kununurra
# Processing Record 13 of Set 13 | whitehorse
# Processing Record 14 of Set 13 | laguna
# Processing Record 15 of Set 13 | lazaro cardenas
# Processing Record 16 of Set 13 | garowe
# Processing Record 17 of Set 13 | campos novos
# Processing Record 18 of Set 13 | tuysarkan
# City not found. Skipping...
# Processing Record 19 of Set 13 | bol
# Processing Record 20 of Set 13 | maykain
# City not found. Skipping...
# Processing Record 21 of Set 13 | oktyabrskoye
# Processing Record 22 of Set 13 | nouadhibou
# Processing Record 23 of Set 13 | bundaberg
# Processing Record 24 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 25 of Set 13 | bandarbeyla
# Processing Record 26 of Set 13 | limni
# Processing Record 27 of Set 13 | talakan
# Processing Record 28 of Set 13 | urengoy
# Processing Record 29 of Set 13 | ugoofaaru
# Processing Record 30 of Set 13 | springdale
# Processing Record 31 of Set 13 | gat
# Processing Record 32 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 13 | geraldton
# Processing Record 34 of Set 13 | san patricio
# Processing Record 35 of Set 13 | gempol
# Processing Record 36 of Set 13 | pingzhuang
# Processing Record 37 of Set 13 | ferme-neuve
# Processing Record 38 of Set 13 | cockburn town
# Processing Record 39 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 13 | sembakung
# Processing Record 41 of Set 13 | adrar
# Processing Record 42 of Set 13 | zenzeli
# Processing Record 43 of Set 13 | palmer
# Processing Record 44 of Set 13 | barcelos
# Processing Record 45 of Set 13 | ambanja
# Processing Record 46 of Set 13 | behshahr
# Processing Record 47 of Set 13 | aswan
# Processing Record 48 of Set 13 | freeport
# Processing Record 49 of Set 13 | mandera
# Processing Record 50 of Set 13 | doha
# Processing Record 1 of Set 14 | novobelokatay
# Processing Record 2 of Set 14 | najran
# Processing Record 3 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 14 | kristiansund
# Processing Record 5 of Set 14 | coalcoman
# City not found. Skipping...
# Processing Record 6 of Set 14 | albino
# Processing Record 7 of Set 14 | tamworth
# Processing Record 8 of Set 14 | auki
# Processing Record 9 of Set 14 | la paz
# Processing Record 10 of Set 14 | cururupu
# Processing Record 11 of Set 14 | sokoni
# Processing Record 12 of Set 14 | vanavara
# Processing Record 13 of Set 14 | faya
# Processing Record 14 of Set 14 | tateyama
# Processing Record 15 of Set 14 | fort saint james
# Processing Record 16 of Set 14 | louga
# Processing Record 17 of Set 14 | hadejia
# Processing Record 18 of Set 14 | balagansk
# Processing Record 19 of Set 14 | mount darwin
# Processing Record 20 of Set 14 | berbera
# Processing Record 21 of Set 14 | sao raimundo nonato
# Processing Record 22 of Set 14 | port augusta
# Processing Record 23 of Set 14 | yuli
# Processing Record 24 of Set 14 | ahipara
# Processing Record 25 of Set 14 | vestmannaeyjar
# Processing Record 26 of Set 14 | sao jose da coroa grande
# Processing Record 27 of Set 14 | kloulklubed
# Processing Record 28 of Set 14 | hefei
# Processing Record 29 of Set 14 | tiarei
# Processing Record 30 of Set 14 | vrangel
# Processing Record 31 of Set 14 | paka
# Processing Record 32 of Set 14 | manadhoo
# Processing Record 33 of Set 14 | kimbe
# Processing Record 34 of Set 14 | puerto del rosario
# Processing Record 35 of Set 14 | ban mo
# Processing Record 36 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 14 | kangaatsiaq
# Processing Record 38 of Set 14 | warqla
# City not found. Skipping...
# Processing Record 39 of Set 14 | mecayapan
# Processing Record 40 of Set 14 | moron
# Processing Record 41 of Set 14 | kuna
# Processing Record 42 of Set 14 | chara
# Processing Record 43 of Set 14 | constitucion
# Processing Record 44 of Set 14 | baruun-urt
# Processing Record 45 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 46 of Set 14 | bistrica
# Processing Record 47 of Set 14 | burgeo
# Processing Record 48 of Set 14 | sola
# Processing Record 49 of Set 14 | ancud
# Processing Record 50 of Set 14 | hutchinson
# Processing Record 1 of Set 15 | sri aman
# Processing Record 2 of Set 15 | westerly
# Processing Record 3 of Set 15 | port blair
# Processing Record 4 of Set 15 | aripuana
# Processing Record 5 of Set 15 | ciudad bolivar
# Processing Record 6 of Set 15 | ciudad guayana
# Processing Record 7 of Set 15 | khilok
# Processing Record 8 of Set 15 | georgiyevka
# Processing Record 9 of Set 15 | jati
# Processing Record 10 of Set 15 | fuerte olimpo
# Processing Record 11 of Set 15 | khor
# Processing Record 12 of Set 15 | santa maria
# Processing Record 13 of Set 15 | tutoia
# Processing Record 14 of Set 15 | henties bay
# Processing Record 15 of Set 15 | majene
# Processing Record 16 of Set 15 | ormara
# Processing Record 17 of Set 15 | wadi
# Processing Record 18 of Set 15 | qandahar
# City not found. Skipping...
# Processing Record 19 of Set 15 | yarada
# Processing Record 20 of Set 15 | vlasotince
# Processing Record 21 of Set 15 | dong hoi
# Processing Record 22 of Set 15 | dwarka
# Processing Record 23 of Set 15 | teknaf
# Processing Record 24 of Set 15 | presidente epitacio
# Processing Record 25 of Set 15 | moose factory
# Processing Record 26 of Set 15 | manicore
# Processing Record 27 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 28 of Set 15 | tongliao
# Processing Record 29 of Set 15 | worthington
# Processing Record 30 of Set 15 | bolanos de calatrava
# Processing Record 31 of Set 15 | ksenyevka
# City not found. Skipping...
# Processing Record 32 of Set 15 | kuji
# Processing Record 33 of Set 15 | jiayuguan
# Processing Record 34 of Set 15 | baie-comeau
# Processing Record 35 of Set 15 | wladyslawowo
# Processing Record 36 of Set 15 | mildura
# Processing Record 37 of Set 15 | afmadu
# City not found. Skipping...
# Processing Record 38 of Set 15 | tucuman
# Processing Record 39 of Set 15 | noumea
# Processing Record 40 of Set 15 | madawaska
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 671

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Malakal   9.5334   31.6605     71.47        93          29
# 1       Bredasdorp -34.5322   20.0403     63.75        89          39
# 2           Damara   4.9608   18.7035     71.13        97         100
# 3     Kruisfontein -34.0033   24.7314     60.89        95           1
# 4          Salalah  17.0151   54.0924     77.09        69           0
# 5   Ribeira Grande  38.5167  -28.7000     67.77        67          96
# 6            Vardo  70.3705   31.1107     30.18        80          99
# 7  Haines Junction  60.7522 -137.5108     39.15        65          84
# 8         Souillac -20.5167   57.5167     71.98        83          40
# 9          Itarema  -2.9248  -39.9167     79.30        79          49
#
#    Wind Speed Country Current Description
# 0        3.62      SS    scattered clouds
# 1       12.86      ZA    scattered clouds
# 2        2.71      CF     overcast clouds
# 3        2.04      ZA           clear sky
# 4        3.44      OM           clear sky
# 5        3.00      PT     overcast clouds
# 6       14.97      NO     overcast clouds
# 7        1.14      CA       broken clouds
# 8        8.05      MU    scattered clouds
# 9       15.50      BR    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0       Malakal      SS   9.5334  31.6605     71.47        93          29
# 1    Bredasdorp      ZA -34.5322  20.0403     63.75        89          39
# 2        Damara      CF   4.9608  18.7035     71.13        97         100
# 3  Kruisfontein      ZA -34.0033  24.7314     60.89        95           1
# 4       Salalah      OM  17.0151  54.0924     77.09        69           0
#
#    Wind Speed Current Description
# 0        3.62    scattered clouds
# 1       12.86    scattered clouds
# 2        2.71     overcast clouds
# 3        2.04           clear sky
# 4        3.44           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "./WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
