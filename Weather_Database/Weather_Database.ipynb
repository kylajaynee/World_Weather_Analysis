# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000, 90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
         cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 762

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | khovu-aksy
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | okhotsk
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | shache
# Processing Record 6 of Set 1 | richards bay
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | bambous virieux
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | thompson
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | taunggyi
# Processing Record 13 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | bose
# Processing Record 16 of Set 1 | klaksvik
# Processing Record 17 of Set 1 | menongue
# Processing Record 18 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | lyuban
# Processing Record 21 of Set 1 | hobyo
# Processing Record 22 of Set 1 | jumla
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | maldonado
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 1 | carauari
# Processing Record 29 of Set 1 | moron
# Processing Record 30 of Set 1 | saint-joseph
# Processing Record 31 of Set 1 | andenes
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | bubaque
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | castro
# Processing Record 36 of Set 1 | hilo
# Processing Record 37 of Set 1 | kharp
# Processing Record 38 of Set 1 | barrow
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | isangel
# Processing Record 41 of Set 1 | mahebourg
# Processing Record 42 of Set 1 | bluff
# Processing Record 43 of Set 1 | parakou
# Processing Record 44 of Set 1 | geraldton
# Processing Record 45 of Set 1 | lakes entrance
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | maniitsoq
# Processing Record 48 of Set 1 | east london
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 1 of Set 2 | burnie
# Processing Record 2 of Set 2 | port elizabeth
# Processing Record 3 of Set 2 | dicabisagan
# Processing Record 4 of Set 2 | sakaiminato
# Processing Record 5 of Set 2 | bredasdorp
# Processing Record 6 of Set 2 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 2 | katherine
# Processing Record 8 of Set 2 | nyurba
# Processing Record 9 of Set 2 | thinadhoo
# Processing Record 10 of Set 2 | hobart
# Processing Record 11 of Set 2 | shelburne
# Processing Record 12 of Set 2 | sioux lookout
# Processing Record 13 of Set 2 | ossora
# Processing Record 14 of Set 2 | tiksi
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | paamiut
# Processing Record 18 of Set 2 | ambulu
# Processing Record 19 of Set 2 | poum
# Processing Record 20 of Set 2 | rawson
# Processing Record 21 of Set 2 | cherskiy
# Processing Record 22 of Set 2 | mar del plata
# Processing Record 23 of Set 2 | bereda
# Processing Record 24 of Set 2 | smithers
# Processing Record 25 of Set 2 | litovko
# Processing Record 26 of Set 2 | port hardy
# Processing Record 27 of Set 2 | airai
# Processing Record 28 of Set 2 | bandarbeyla
# Processing Record 29 of Set 2 | ajdabiya
# Processing Record 30 of Set 2 | upernavik
# Processing Record 31 of Set 2 | maputo
# Processing Record 32 of Set 2 | komsomolskiy
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | esperance
# Processing Record 35 of Set 2 | bengkulu
# Processing Record 36 of Set 2 | kapaa
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | conchas
# Processing Record 39 of Set 2 | zerbst
# Processing Record 40 of Set 2 | luderitz
# Processing Record 41 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 42 of Set 2 | puerto baquerizo moreno
# Processing Record 43 of Set 2 | port blair
# Processing Record 44 of Set 2 | abiy adi
# City not found. Skipping...
# Processing Record 45 of Set 2 | kayes
# Processing Record 46 of Set 2 | chokurdakh
# Processing Record 47 of Set 2 | auki
# Processing Record 48 of Set 2 | padang
# Processing Record 49 of Set 2 | mucurapo
# Processing Record 50 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 3 | viedma
# Processing Record 2 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 3 | roald
# Processing Record 4 of Set 3 | tornio
# Processing Record 5 of Set 3 | bedele
# Processing Record 6 of Set 3 | kupang
# Processing Record 7 of Set 3 | san rafael
# Processing Record 8 of Set 3 | atuona
# Processing Record 9 of Set 3 | yagodnoye
# Processing Record 10 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 11 of Set 3 | muyezerskiy
# Processing Record 12 of Set 3 | la ronge
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | mega
# Processing Record 15 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 3 | bud
# Processing Record 17 of Set 3 | laguna
# Processing Record 18 of Set 3 | phalaborwa
# Processing Record 19 of Set 3 | lorengau
# Processing Record 20 of Set 3 | kodiak
# Processing Record 21 of Set 3 | cap-aux-meules
# Processing Record 22 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 3 | abu dhabi
# Processing Record 24 of Set 3 | weyburn
# Processing Record 25 of Set 3 | chuy
# Processing Record 26 of Set 3 | punta arenas
# Processing Record 27 of Set 3 | townsville
# Processing Record 28 of Set 3 | westport
# Processing Record 29 of Set 3 | tiznit
# Processing Record 30 of Set 3 | qaqortoq
# Processing Record 31 of Set 3 | samana
# Processing Record 32 of Set 3 | sao filipe
# Processing Record 33 of Set 3 | bethel
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | kununurra
# Processing Record 36 of Set 3 | pingliang
# Processing Record 37 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 3 | manitouwadge
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | mayumba
# Processing Record 41 of Set 3 | kamenka
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | lasa
# Processing Record 44 of Set 3 | sao joao da barra
# Processing Record 45 of Set 3 | palauig
# Processing Record 46 of Set 3 | riyadh
# Processing Record 47 of Set 3 | waipawa
# Processing Record 48 of Set 3 | botwood
# Processing Record 49 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 3 | mehamn
# Processing Record 1 of Set 4 | merauke
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | college
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | alamosa
# Processing Record 6 of Set 4 | liberal
# Processing Record 7 of Set 4 | qaanaaq
# Processing Record 8 of Set 4 | georgetown
# Processing Record 9 of Set 4 | elko
# Processing Record 10 of Set 4 | lebu
# Processing Record 11 of Set 4 | nova russas
# Processing Record 12 of Set 4 | coquimbo
# Processing Record 13 of Set 4 | grand gaube
# Processing Record 14 of Set 4 | silifke
# Processing Record 15 of Set 4 | paracatu
# Processing Record 16 of Set 4 | vallenar
# Processing Record 17 of Set 4 | tabou
# Processing Record 18 of Set 4 | druzhba
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | hofn
# Processing Record 21 of Set 4 | nanortalik
# Processing Record 22 of Set 4 | atar
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | pierre
# Processing Record 25 of Set 4 | pevek
# Processing Record 26 of Set 4 | omboue
# Processing Record 27 of Set 4 | tasiilaq
# Processing Record 28 of Set 4 | fenoarivo
# Processing Record 29 of Set 4 | leningradskiy
# Processing Record 30 of Set 4 | virginia beach
# Processing Record 31 of Set 4 | carnarvon
# Processing Record 32 of Set 4 | lerwick
# Processing Record 33 of Set 4 | pangnirtung
# Processing Record 34 of Set 4 | karratha
# Processing Record 35 of Set 4 | santiago del estero
# Processing Record 36 of Set 4 | beloha
# Processing Record 37 of Set 4 | flin flon
# Processing Record 38 of Set 4 | laranja da terra
# Processing Record 39 of Set 4 | tateyama
# Processing Record 40 of Set 4 | ngaoundere
# Processing Record 41 of Set 4 | kidal
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | lompoc
# Processing Record 44 of Set 4 | beringovskiy
# Processing Record 45 of Set 4 | yellowknife
# Processing Record 46 of Set 4 | shimoda
# Processing Record 47 of Set 4 | nalut
# Processing Record 48 of Set 4 | flinders
# Processing Record 49 of Set 4 | laurel
# Processing Record 50 of Set 4 | siraha
# Processing Record 1 of Set 5 | krasnovishersk
# Processing Record 2 of Set 5 | saskylakh
# Processing Record 3 of Set 5 | san quintin
# Processing Record 4 of Set 5 | lloydminster
# Processing Record 5 of Set 5 | marsh harbour
# Processing Record 6 of Set 5 | jizan
# Processing Record 7 of Set 5 | araruna
# Processing Record 8 of Set 5 | praia da vitoria
# Processing Record 9 of Set 5 | narsaq
# Processing Record 10 of Set 5 | qasigiannguit
# Processing Record 11 of Set 5 | inta
# Processing Record 12 of Set 5 | ayr
# Processing Record 13 of Set 5 | arlit
# Processing Record 14 of Set 5 | san policarpo
# Processing Record 15 of Set 5 | wazzan
# City not found. Skipping...
# Processing Record 16 of Set 5 | beyneu
# Processing Record 17 of Set 5 | luis correia
# Processing Record 18 of Set 5 | gubkinskiy
# Processing Record 19 of Set 5 | khammam
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | olga
# Processing Record 22 of Set 5 | adrar
# Processing Record 23 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 24 of Set 5 | los llanos de aridane
# Processing Record 25 of Set 5 | alfred
# Processing Record 26 of Set 5 | havre-saint-pierre
# Processing Record 27 of Set 5 | provideniya
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 5 | tual
# Processing Record 31 of Set 5 | cam ranh
# Processing Record 32 of Set 5 | eureka
# Processing Record 33 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 5 | hasaki
# Processing Record 35 of Set 5 | black river
# Processing Record 36 of Set 5 | san pedro
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | tuktoyaktuk
# Processing Record 39 of Set 5 | denison
# Processing Record 40 of Set 5 | lavrentiya
# Processing Record 41 of Set 5 | cabedelo
# Processing Record 42 of Set 5 | butterworth
# Processing Record 43 of Set 5 | oranjemund
# Processing Record 44 of Set 5 | inirida
# Processing Record 45 of Set 5 | iqaluit
# Processing Record 46 of Set 5 | victoria
# Processing Record 47 of Set 5 | catamarca
# Processing Record 48 of Set 5 | hailar
# Processing Record 49 of Set 5 | dikson
# Processing Record 50 of Set 5 | kirriemuir
# Processing Record 1 of Set 6 | buseresere
# Processing Record 2 of Set 6 | dickinson
# Processing Record 3 of Set 6 | yuzhno-kurilsk
# Processing Record 4 of Set 6 | grindavik
# Processing Record 5 of Set 6 | aleksandrov gay
# Processing Record 6 of Set 6 | dolinsk
# Processing Record 7 of Set 6 | taoudenni
# Processing Record 8 of Set 6 | atambua
# Processing Record 9 of Set 6 | sasebo
# Processing Record 10 of Set 6 | saint-leu
# Processing Record 11 of Set 6 | invermere
# Processing Record 12 of Set 6 | ambilobe
# Processing Record 13 of Set 6 | puerto ayora
# Processing Record 14 of Set 6 | egvekinot
# Processing Record 15 of Set 6 | weligama
# Processing Record 16 of Set 6 | vyartsilya
# Processing Record 17 of Set 6 | boende
# Processing Record 18 of Set 6 | khandyga
# Processing Record 19 of Set 6 | gold coast
# Processing Record 20 of Set 6 | shelton
# Processing Record 21 of Set 6 | angoram
# Processing Record 22 of Set 6 | nemuro
# Processing Record 23 of Set 6 | banda aceh
# Processing Record 24 of Set 6 | half moon bay
# Processing Record 25 of Set 6 | kahului
# Processing Record 26 of Set 6 | tumarbong
# Processing Record 27 of Set 6 | copiapo
# Processing Record 28 of Set 6 | kavieng
# Processing Record 29 of Set 6 | hanstholm
# Processing Record 30 of Set 6 | oban
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | paredon
# Processing Record 33 of Set 6 | san vicente
# Processing Record 34 of Set 6 | olafsvik
# Processing Record 35 of Set 6 | oranjestad
# Processing Record 36 of Set 6 | ribeira grande
# Processing Record 37 of Set 6 | praya
# Processing Record 38 of Set 6 | baykit
# Processing Record 39 of Set 6 | subtanjalla
# Processing Record 40 of Set 6 | xiamen
# Processing Record 41 of Set 6 | constitucion
# Processing Record 42 of Set 6 | progreso
# Processing Record 43 of Set 6 | hithadhoo
# Processing Record 44 of Set 6 | codrington
# Processing Record 45 of Set 6 | buala
# Processing Record 46 of Set 6 | chimbarongo
# Processing Record 47 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 48 of Set 6 | kavali
# Processing Record 49 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 50 of Set 6 | chadan
# Processing Record 1 of Set 7 | mercedes
# Processing Record 2 of Set 7 | nome
# Processing Record 3 of Set 7 | lethem
# Processing Record 4 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 5 of Set 7 | makakilo city
# Processing Record 6 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 7 | dinguiraye
# Processing Record 8 of Set 7 | strai
# Processing Record 9 of Set 7 | resistencia
# Processing Record 10 of Set 7 | macara
# Processing Record 11 of Set 7 | raga
# Processing Record 12 of Set 7 | cabo san lucas
# Processing Record 13 of Set 7 | manati
# Processing Record 14 of Set 7 | nyrob
# Processing Record 15 of Set 7 | calderitas
# Processing Record 16 of Set 7 | souillac
# Processing Record 17 of Set 7 | beauvais
# Processing Record 18 of Set 7 | betong
# Processing Record 19 of Set 7 | vao
# Processing Record 20 of Set 7 | broome
# Processing Record 21 of Set 7 | rio grande
# Processing Record 22 of Set 7 | zhigansk
# Processing Record 23 of Set 7 | bosaso
# Processing Record 24 of Set 7 | usinsk
# Processing Record 25 of Set 7 | norman wells
# Processing Record 26 of Set 7 | cockburn town
# Processing Record 27 of Set 7 | denpasar
# Processing Record 28 of Set 7 | kemin
# Processing Record 29 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 30 of Set 7 | newtownards
# Processing Record 31 of Set 7 | nisia floresta
# Processing Record 32 of Set 7 | bahia blanca
# Processing Record 33 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 34 of Set 7 | juneau
# Processing Record 35 of Set 7 | vila velha
# Processing Record 36 of Set 7 | husavik
# Processing Record 37 of Set 7 | sindand
# City not found. Skipping...
# Processing Record 38 of Set 7 | bafra
# Processing Record 39 of Set 7 | finschhafen
# Processing Record 40 of Set 7 | kolaras
# Processing Record 41 of Set 7 | edd
# Processing Record 42 of Set 7 | akureyri
# Processing Record 43 of Set 7 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 7 | hamilton
# Processing Record 45 of Set 7 | longhua
# Processing Record 46 of Set 7 | slonim
# Processing Record 47 of Set 7 | seoul
# Processing Record 48 of Set 7 | salalah
# Processing Record 49 of Set 7 | cayenne
# Processing Record 50 of Set 7 | bonavista
# Processing Record 1 of Set 8 | kamaishi
# Processing Record 2 of Set 8 | sabang
# Processing Record 3 of Set 8 | lokosovo
# Processing Record 4 of Set 8 | ipiau
# Processing Record 5 of Set 8 | bac lieu
# Processing Record 6 of Set 8 | pangai
# Processing Record 7 of Set 8 | killybegs
# Processing Record 8 of Set 8 | anloga
# Processing Record 9 of Set 8 | beira
# Processing Record 10 of Set 8 | griffith
# Processing Record 11 of Set 8 | baesweiler
# Processing Record 12 of Set 8 | nara
# Processing Record 13 of Set 8 | mount isa
# Processing Record 14 of Set 8 | gaoyou
# Processing Record 15 of Set 8 | nioro
# Processing Record 16 of Set 8 | winnemucca
# Processing Record 17 of Set 8 | pedernales
# Processing Record 18 of Set 8 | ati
# Processing Record 19 of Set 8 | ust-kuyga
# Processing Record 20 of Set 8 | tatawin
# Processing Record 21 of Set 8 | key west
# Processing Record 22 of Set 8 | yakeshi
# Processing Record 23 of Set 8 | kushima
# Processing Record 24 of Set 8 | kirensk
# Processing Record 25 of Set 8 | havelock
# Processing Record 26 of Set 8 | clyde river
# Processing Record 27 of Set 8 | whitianga
# Processing Record 28 of Set 8 | ormara
# Processing Record 29 of Set 8 | ariquemes
# Processing Record 30 of Set 8 | puerto leguizamo
# Processing Record 31 of Set 8 | praia
# Processing Record 32 of Set 8 | barra
# Processing Record 33 of Set 8 | alofi
# Processing Record 34 of Set 8 | hearst
# Processing Record 35 of Set 8 | donji vakuf
# Processing Record 36 of Set 8 | kavaratti
# Processing Record 37 of Set 8 | kabare
# Processing Record 38 of Set 8 | meadow lake
# Processing Record 39 of Set 8 | kruisfontein
# Processing Record 40 of Set 8 | meulaboh
# Processing Record 41 of Set 8 | cap malheureux
# Processing Record 42 of Set 8 | mungaa
# Processing Record 43 of Set 8 | guerrero negro
# Processing Record 44 of Set 8 | tomatlan
# Processing Record 45 of Set 8 | vostok
# Processing Record 46 of Set 8 | mount gambier
# Processing Record 47 of Set 8 | cicero dantas
# Processing Record 48 of Set 8 | molteno
# Processing Record 49 of Set 8 | bani
# Processing Record 50 of Set 8 | betare oya
# Processing Record 1 of Set 9 | comodoro rivadavia
# Processing Record 2 of Set 9 | lata
# Processing Record 3 of Set 9 | lumphat
# Processing Record 4 of Set 9 | fujin
# Processing Record 5 of Set 9 | skibbereen
# Processing Record 6 of Set 9 | faanui
# Processing Record 7 of Set 9 | piranhas
# Processing Record 8 of Set 9 | nautla
# Processing Record 9 of Set 9 | kisangani
# Processing Record 10 of Set 9 | hualmay
# Processing Record 11 of Set 9 | turan
# Processing Record 12 of Set 9 | anadyr
# Processing Record 13 of Set 9 | yarmouth
# Processing Record 14 of Set 9 | kismayo
# Processing Record 15 of Set 9 | avera
# Processing Record 16 of Set 9 | orotukan
# Processing Record 17 of Set 9 | adre
# Processing Record 18 of Set 9 | aksu
# Processing Record 19 of Set 9 | avarua
# Processing Record 20 of Set 9 | alice springs
# Processing Record 21 of Set 9 | belaya gora
# Processing Record 22 of Set 9 | antofagasta
# Processing Record 23 of Set 9 | ancud
# Processing Record 24 of Set 9 | trairi
# Processing Record 25 of Set 9 | bowen
# Processing Record 26 of Set 9 | barabai
# Processing Record 27 of Set 9 | igarka
# Processing Record 28 of Set 9 | provins
# Processing Record 29 of Set 9 | afgoye
# City not found. Skipping...
# Processing Record 30 of Set 9 | tessalit
# Processing Record 31 of Set 9 | general pico
# Processing Record 32 of Set 9 | orange cove
# Processing Record 33 of Set 9 | iisalmi
# Processing Record 34 of Set 9 | sampit
# Processing Record 35 of Set 9 | nioki
# Processing Record 36 of Set 9 | porto walter
# Processing Record 37 of Set 9 | talladega
# Processing Record 38 of Set 9 | bage
# Processing Record 39 of Set 9 | ruian
# City not found. Skipping...
# Processing Record 40 of Set 9 | christchurch
# Processing Record 41 of Set 9 | dingle
# Processing Record 42 of Set 9 | turayf
# Processing Record 43 of Set 9 | urengoy
# Processing Record 44 of Set 9 | noumea
# Processing Record 45 of Set 9 | tallahassee
# Processing Record 46 of Set 9 | zavetnoye
# Processing Record 47 of Set 9 | sirvintos
# Processing Record 48 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 49 of Set 9 | pacific grove
# Processing Record 50 of Set 9 | anshun
# Processing Record 1 of Set 10 | olinda
# Processing Record 2 of Set 10 | balkhash
# Processing Record 3 of Set 10 | porbandar
# Processing Record 4 of Set 10 | kathu
# Processing Record 5 of Set 10 | marsa matruh
# Processing Record 6 of Set 10 | berlevag
# Processing Record 7 of Set 10 | zharkent
# Processing Record 8 of Set 10 | suba
# Processing Record 9 of Set 10 | nabire
# Processing Record 10 of Set 10 | kintore
# Processing Record 11 of Set 10 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 10 | gasa
# Processing Record 13 of Set 10 | arica
# Processing Record 14 of Set 10 | saint-georges
# Processing Record 15 of Set 10 | yefira
# City not found. Skipping...
# Processing Record 16 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 17 of Set 10 | horsham
# Processing Record 18 of Set 10 | bathsheba
# Processing Record 19 of Set 10 | paita
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | bar harbor
# Processing Record 23 of Set 10 | acarau
# Processing Record 24 of Set 10 | anupgarh
# Processing Record 25 of Set 10 | cabatuan
# Processing Record 26 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 10 | odweyne
# Processing Record 28 of Set 10 | tabriz
# Processing Record 29 of Set 10 | dondo
# Processing Record 30 of Set 10 | acapulco
# Processing Record 31 of Set 10 | haines junction
# Processing Record 32 of Set 10 | arcata
# Processing Record 33 of Set 10 | kowary
# Processing Record 34 of Set 10 | glinka
# Processing Record 35 of Set 10 | lujan
# Processing Record 36 of Set 10 | genc
# Processing Record 37 of Set 10 | kenai
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | aykhal
# Processing Record 40 of Set 10 | goure
# Processing Record 41 of Set 10 | alta floresta
# Processing Record 42 of Set 10 | nantucket
# Processing Record 43 of Set 10 | tahta
# Processing Record 44 of Set 10 | puerto escondido
# Processing Record 45 of Set 10 | new ulm
# Processing Record 46 of Set 10 | karpathos
# Processing Record 47 of Set 10 | sobolevo
# Processing Record 48 of Set 10 | ryotsu
# Processing Record 49 of Set 10 | larap
# Processing Record 50 of Set 10 | saint anthony
# Processing Record 1 of Set 11 | khopoli
# Processing Record 2 of Set 11 | fayaoue
# Processing Record 3 of Set 11 | broken hill
# Processing Record 4 of Set 11 | yumen
# Processing Record 5 of Set 11 | tirlyanskiy
# Processing Record 6 of Set 11 | kabo
# Processing Record 7 of Set 11 | san gabriel casa blanca
# Processing Record 8 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 9 of Set 11 | maralal
# Processing Record 10 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 11 | necochea
# Processing Record 12 of Set 11 | guadalupe y calvo
# Processing Record 13 of Set 11 | tabialan
# City not found. Skipping...
# Processing Record 14 of Set 11 | agirish
# Processing Record 15 of Set 11 | aasiaat
# Processing Record 16 of Set 11 | deputatskiy
# Processing Record 17 of Set 11 | bafq
# Processing Record 18 of Set 11 | tromso
# Processing Record 19 of Set 11 | strelka
# Processing Record 20 of Set 11 | lujiang
# Processing Record 21 of Set 11 | rio esteban
# Processing Record 22 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 23 of Set 11 | volosovo
# Processing Record 24 of Set 11 | tongliao
# Processing Record 25 of Set 11 | mampong
# Processing Record 26 of Set 11 | roswell
# Processing Record 27 of Set 11 | coolum beach
# Processing Record 28 of Set 11 | itarema
# Processing Record 29 of Set 11 | ibra
# Processing Record 30 of Set 11 | saint-louis
# Processing Record 31 of Set 11 | naze
# Processing Record 32 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 11 | alexandria
# Processing Record 34 of Set 11 | panjab
# Processing Record 35 of Set 11 | garden city
# Processing Record 36 of Set 11 | umm bab
# Processing Record 37 of Set 11 | santa rosa
# Processing Record 38 of Set 11 | zyryanka
# Processing Record 39 of Set 11 | brigantine
# Processing Record 40 of Set 11 | kloulklubed
# Processing Record 41 of Set 11 | agadir
# Processing Record 42 of Set 11 | kimbe
# Processing Record 43 of Set 11 | minot
# Processing Record 44 of Set 11 | safaga
# Processing Record 45 of Set 11 | ranfurly
# Processing Record 46 of Set 11 | svay rieng
# Processing Record 47 of Set 11 | yulara
# Processing Record 48 of Set 11 | muros
# Processing Record 49 of Set 11 | soissons
# Processing Record 50 of Set 11 | lopsmarka
# Processing Record 1 of Set 12 | waingapu
# Processing Record 2 of Set 12 | wagar
# Processing Record 3 of Set 12 | ovalle
# Processing Record 4 of Set 12 | the valley
# Processing Record 5 of Set 12 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 12 | port-gentil
# Processing Record 7 of Set 12 | sorrento
# Processing Record 8 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 9 of Set 12 | tanout
# Processing Record 10 of Set 12 | honningsvag
# Processing Record 11 of Set 12 | visnes
# Processing Record 12 of Set 12 | ayagoz
# Processing Record 13 of Set 12 | hunchun
# Processing Record 14 of Set 12 | obidos
# Processing Record 15 of Set 12 | dianopolis
# City not found. Skipping...
# Processing Record 16 of Set 12 | seoni malwa
# Processing Record 17 of Set 12 | turukhansk
# Processing Record 18 of Set 12 | radom
# Processing Record 19 of Set 12 | tutoia
# Processing Record 20 of Set 12 | honiara
# Processing Record 21 of Set 12 | havoysund
# Processing Record 22 of Set 12 | gillette
# Processing Record 23 of Set 12 | nicoya
# Processing Record 24 of Set 12 | valley city
# Processing Record 25 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 12 | las cruces
# Processing Record 27 of Set 12 | mitsamiouli
# Processing Record 28 of Set 12 | saint-paul
# Processing Record 29 of Set 12 | itupiranga
# Processing Record 30 of Set 12 | rafraf
# Processing Record 31 of Set 12 | magomeni
# Processing Record 32 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 33 of Set 12 | morant bay
# Processing Record 34 of Set 12 | sitka
# Processing Record 35 of Set 12 | manadhoo
# Processing Record 36 of Set 12 | san angelo
# Processing Record 37 of Set 12 | inderka
# Processing Record 38 of Set 12 | orsha
# Processing Record 39 of Set 12 | morehead
# Processing Record 40 of Set 12 | lewiston
# Processing Record 41 of Set 12 | yuncheng
# Processing Record 42 of Set 12 | boueni
# Processing Record 43 of Set 12 | saint george
# Processing Record 44 of Set 12 | chardara
# Processing Record 45 of Set 12 | hatillo
# Processing Record 46 of Set 12 | floro
# Processing Record 47 of Set 12 | galle
# Processing Record 48 of Set 12 | sorsk
# Processing Record 49 of Set 12 | caravelas
# Processing Record 50 of Set 12 | dukat
# Processing Record 1 of Set 13 | paka
# Processing Record 2 of Set 13 | wanning
# Processing Record 3 of Set 13 | acari
# Processing Record 4 of Set 13 | chingirlau
# Processing Record 5 of Set 13 | jiblah
# Processing Record 6 of Set 13 | touros
# Processing Record 7 of Set 13 | matara
# Processing Record 8 of Set 13 | andevoranto
# City not found. Skipping...
# Processing Record 9 of Set 13 | russas
# Processing Record 10 of Set 13 | plettenberg bay
# Processing Record 11 of Set 13 | udachnyy
# Processing Record 12 of Set 13 | namatanai
# Processing Record 13 of Set 13 | lazaro cardenas
# Processing Record 14 of Set 13 | russkaya polyana
# Processing Record 15 of Set 13 | berbera
# Processing Record 16 of Set 13 | francistown
# Processing Record 17 of Set 13 | bilibino
# Processing Record 18 of Set 13 | ndjole
# Processing Record 19 of Set 13 | santa lucia
# Processing Record 20 of Set 13 | ankazobe
# Processing Record 21 of Set 13 | qena
# Processing Record 22 of Set 13 | yabelo
# Processing Record 23 of Set 13 | baherden
# Processing Record 24 of Set 13 | markivka
# Processing Record 25 of Set 13 | port lincoln
# Processing Record 26 of Set 13 | udarnyy
# Processing Record 27 of Set 13 | vieques
# Processing Record 28 of Set 13 | attawapiskat
# City not found. Skipping...
# Processing Record 29 of Set 13 | novaya lyalya
# Processing Record 30 of Set 13 | vila do maio
# Processing Record 31 of Set 13 | shetpe
# Processing Record 32 of Set 13 | guangzhou
# Processing Record 33 of Set 13 | fortuna
# Processing Record 34 of Set 13 | las palmas
# Processing Record 35 of Set 13 | keti bandar
# Processing Record 36 of Set 13 | talnakh
# Processing Record 37 of Set 13 | jijiga
# Processing Record 38 of Set 13 | neiafu
# Processing Record 39 of Set 13 | canico
# Processing Record 40 of Set 13 | talitsa
# Processing Record 41 of Set 13 | shimanovsk
# Processing Record 42 of Set 13 | chiredzi
# Processing Record 43 of Set 13 | ovsyanka
# Processing Record 44 of Set 13 | marienburg
# Processing Record 45 of Set 13 | palmerston
# Processing Record 46 of Set 13 | avila
# Processing Record 47 of Set 13 | malko tarnovo
# Processing Record 48 of Set 13 | north myrtle beach
# Processing Record 49 of Set 13 | smirnykh
# Processing Record 50 of Set 13 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 14 | vila franca do campo
# Processing Record 2 of Set 14 | farah
# Processing Record 3 of Set 14 | ostrovnoy
# Processing Record 4 of Set 14 | namibe
# Processing Record 5 of Set 14 | sinnamary
# Processing Record 6 of Set 14 | fukue
# Processing Record 7 of Set 14 | lagunas
# Processing Record 8 of Set 14 | miyang
# Processing Record 9 of Set 14 | bull savanna
# Processing Record 10 of Set 14 | khvastovichi
# Processing Record 11 of Set 14 | teya
# Processing Record 12 of Set 14 | lamas
# Processing Record 13 of Set 14 | izmalkovo
# Processing Record 14 of Set 14 | jinchang
# Processing Record 15 of Set 14 | angoche
# Processing Record 16 of Set 14 | fare
# Processing Record 17 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 14 | chapais
# Processing Record 19 of Set 14 | bria
# Processing Record 20 of Set 14 | muisne
# Processing Record 21 of Set 14 | madison
# Processing Record 22 of Set 14 | aswan
# Processing Record 23 of Set 14 | portland
# Processing Record 24 of Set 14 | vestmanna
# Processing Record 25 of Set 14 | el wasta
# City not found. Skipping...
# Processing Record 26 of Set 14 | barhiya
# Processing Record 27 of Set 14 | khristoforovo
# City not found. Skipping...
# Processing Record 28 of Set 14 | vila
# Processing Record 29 of Set 14 | mhasla
# Processing Record 30 of Set 14 | abha
# Processing Record 31 of Set 14 | mendi
# Processing Record 32 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 14 | vibo valentia
# Processing Record 34 of Set 14 | berdigestyakh
# Processing Record 35 of Set 14 | byron bay
# Processing Record 36 of Set 14 | harindanga
# Processing Record 37 of Set 14 | bazarnyye mataki
# Processing Record 38 of Set 14 | akyab
# Processing Record 39 of Set 14 | esna
# Processing Record 40 of Set 14 | partizanskoye
# Processing Record 41 of Set 14 | homer
# Processing Record 42 of Set 14 | mwinilunga
# Processing Record 43 of Set 14 | brae
# Processing Record 44 of Set 14 | tabukiniberu
# City not found. Skipping...
# Processing Record 45 of Set 14 | kuytun
# Processing Record 46 of Set 14 | port hawkesbury
# Processing Record 47 of Set 14 | sao jose da coroa grande
# Processing Record 48 of Set 14 | kaeo
# Processing Record 49 of Set 14 | elverum
# Processing Record 50 of Set 14 | fershampenuaz
# Processing Record 1 of Set 15 | aqtobe
# Processing Record 2 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 3 of Set 15 | kutum
# Processing Record 4 of Set 15 | dawei
# Processing Record 5 of Set 15 | frankfort
# Processing Record 6 of Set 15 | snezhnogorsk
# Processing Record 7 of Set 15 | kokopo
# Processing Record 8 of Set 15 | plouzane
# Processing Record 9 of Set 15 | santa marta
# Processing Record 10 of Set 15 | kijang
# Processing Record 11 of Set 15 | labuhan
# Processing Record 12 of Set 15 | acajutla
# Processing Record 13 of Set 15 | sudak
# Processing Record 14 of Set 15 | vestmannaeyjar
# Processing Record 15 of Set 15 | vanavara
# Processing Record 16 of Set 15 | paramonga
# Processing Record 17 of Set 15 | sur
# Processing Record 18 of Set 15 | okha
# Processing Record 19 of Set 15 | coihaique
# Processing Record 20 of Set 15 | buriti alegre
# Processing Record 21 of Set 15 | arkhara
# Processing Record 22 of Set 15 | karaman
# Processing Record 23 of Set 15 | mundi
# Processing Record 24 of Set 15 | rakhya
# City not found. Skipping...
# Processing Record 25 of Set 15 | ibia
# Processing Record 26 of Set 15 | baldeo
# Processing Record 27 of Set 15 | rehoboth
# Processing Record 28 of Set 15 | cartagena
# Processing Record 29 of Set 15 | verkhoyansk
# Processing Record 30 of Set 15 | osoyoos
# Processing Record 31 of Set 15 | coxim
# Processing Record 32 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 15 | matamoros
# Processing Record 34 of Set 15 | antsohihy
# Processing Record 35 of Set 15 | roma
# Processing Record 36 of Set 15 | qui nhon
# Processing Record 37 of Set 15 | east wenatchee bench
# Processing Record 38 of Set 15 | vardo
# Processing Record 39 of Set 15 | naujoji akmene
# Processing Record 40 of Set 15 | iquique
# Processing Record 41 of Set 15 | tabuk
# Processing Record 42 of Set 15 | chepareria
# Processing Record 43 of Set 15 | pinega
# Processing Record 44 of Set 15 | vir
# Processing Record 45 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 15 | itaituba
# Processing Record 47 of Set 15 | kysyl-syr
# Processing Record 48 of Set 15 | itaueira
# Processing Record 49 of Set 15 | kawalu
# Processing Record 50 of Set 15 | sawtell
# Processing Record 1 of Set 16 | pirajui
# Processing Record 2 of Set 16 | dasoguz
# Processing Record 3 of Set 16 | grootfontein
# Processing Record 4 of Set 16 | marawi
# Processing Record 5 of Set 16 | prainha
# Processing Record 6 of Set 16 | kasongo-lunda
# Processing Record 7 of Set 16 | arawa
# Processing Record 8 of Set 16 | boyolangu
# Processing Record 9 of Set 16 | abrau-dyurso
# Processing Record 10 of Set 16 | ahipara
# Processing Record 11 of Set 16 | imbituba
# Processing Record 12 of Set 16 | verkhnyaya inta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 705

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Khovu-Aksy  51.1333   93.6000     32.85        53          58
# 1          Mataura -46.1927  168.8643     56.48        90          97
# 2          Okhotsk  59.3833  143.3000     26.73        38          11
# 3          Ushuaia -54.8000  -68.3000     35.26        87          40
# 4           Shache  38.4167   77.2406     58.91        27          99
# 5     Richards Bay -28.7830   32.0377     71.55        77          75
# 6           Albany  42.6001  -73.9662     42.22        81          58
# 7  Bambous Virieux -20.3428   57.7575     72.21        77          20
# 8      Port Alfred -33.5906   26.8910     68.18        87          61
# 9         Thompson  55.7435  -97.8558     32.16       100         100
#
#    Wind Speed Country                 Date
# 0        1.90      RU  2022-10-20 03:21:49
# 1       13.20      NZ  2022-10-20 03:21:26
# 2       16.40      RU  2022-10-20 03:21:49
# 3       11.50      AR  2022-10-20 03:21:37
# 4        4.56      CN  2022-10-20 03:21:50
# 5       11.72      ZA  2022-10-20 03:21:50
# 6        6.69      US  2022-10-20 03:20:46
# 7        0.00      MU  2022-10-20 03:21:51
# 8        1.01      ZA  2022-10-20 03:21:51
# 9        2.30      CA  2022-10-20 03:21:52

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12600\2750112786.py in <module>
#       4
#       5 # Recreate the DataFrame by using the new column order
# ----> 6 city_data_df = city_data_df[new_column_order]
#       7
#       8 # Display sample data
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['Current Description'] not in index"

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
